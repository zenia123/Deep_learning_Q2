# %% [markdown]
# # Assignment: Ionosphere Data Problem
#
# ### Dataset Description:
#
# This radar data was collected by a system in Goose Bay, Labrador. This system consists of a phased array of 16 high-frequency antennas with a total transmitted power on the order of 6.4 kilowatts. See the paper for more details. The targets were free electrons in the ionosphere. "Good" radar returns are those showing evidence of some type of structure in the ionosphere. "Bad" returns are those that do not; their signals pass through the ionosphere.
#
# Received signals were processed using an autocorrelation function whose arguments are the time of a pulse and the pulse number. There were 17 pulse numbers for the Goose Bay system. Instances in this databse are described by 2 attributes per pulse number, corresponding to the complex values returned by the function resulting from the complex electromagnetic signal.
#
# ### Attribute Information:
#
# - All 34 are continuous
# - The 35th attribute is either "good" or "bad" according to the definition summarized above. This is a binary classification task.
#
#  <br><br>
#
# <table border="1"  cellpadding="6">
# 	<tbody>
#         <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Data Set Characteristics:&nbsp;&nbsp;</b></p></td>
# 		<td><p class="normal">Multivariate</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Instances:</b></p></td>
# 		<td><p class="normal">351</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Area:</b></p></td>
# 		<td><p class="normal">Physical</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#         <tr>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Attribute Characteristics:</b></p></td>
#             <td><p class="normal">Integer,Real</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Number of Attributes:</b></p></td>
#             <td><p class="normal">34</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Date Donated</b></p></td>
#             <td><p class="normal">N/A</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#     <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Associated Tasks:</b></p></td>
# 		<td><p class="normal">Classification</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Missing Values?</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Web Hits:</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 	</tr>
#     </tbody>
#     </table>

# %% [markdown]
# ### WORKFLOW :
# - Load Data .

# %% [markdown]
# # Load Data:
# [Click Here to Download DataSet](https://github.com/ramsha275/ML_Datasets/blob/main/ionosphere_data.csv)

# %% [markdown]
# Loading data...

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the dataset.
df = pd.read_csv('ionosphere_data.csv', delimiter=',')

# %%
# Find the shape of the dataset 
df.shape
# Out:
# (351, 35)

# %% [markdown]
# It's clear from the shape of the data that dataset is not a huge one..

# %%
df.head()
# Out:
#    feature1  feature2  feature3  feature4  feature5  feature6  feature7  \
# 0         1         0   0.99539  -0.05889   0.85243   0.02306   0.83398
# 1         1         0   1.00000  -0.18829   0.93035  -0.36156  -0.10868
# 2         1         0   1.00000  -0.03365   1.00000   0.00485   1.00000
# 3         1         0   1.00000  -0.45161   1.00000   1.00000   0.71216
# 4         1         0   1.00000  -0.02401   0.94140   0.06531   0.92106
#
#    feature8  feature9  feature10  ...  feature26  feature27  feature28  \
# 0  -0.37708   1.00000    0.03760  ...   -0.51171    0.41078   -0.46168
# 1  -0.93597   1.00000   -0.04549  ...   -0.26569   -0.20468   -0.18401
# 2  -0.12062   0.88965    0.01198  ...   -0.40220    0.58984   -0.22145
# 3  -1.00000   0.00000    0.00000  ...    0.90695    0.51613    1.00000
# 4  -0.23255   0.77152   -0.16399  ...   -0.65158    0.13290   -0.53206
#
#    feature29  feature30  feature31  feature32  feature33  feature34  label
# 0    0.21266   -0.34090    0.42267   -0.54487    0.18641   -0.45300      g
# 1   -0.19040   -0.11593   -0.16626   -0.06288   -0.13738   -0.02447      b
# 2    0.43100   -0.17365    0.60436   -0.24180    0.56045   -0.38238      g
# 3    1.00000   -0.20099    0.25682    1.00000   -0.32382    1.00000      b
# 4    0.02431   -0.62197   -0.05707   -0.59573   -0.04608   -0.65697      g
#
# [5 rows x 35 columns]

# %%
df.describe().T
# Out:
#            count      mean       std  min       25%      50%       75%  max
# feature1   351.0  0.891738  0.311155  0.0  1.000000  1.00000  1.000000  1.0
# feature2   351.0  0.000000  0.000000  0.0  0.000000  0.00000  0.000000  0.0
# feature3   351.0  0.641342  0.497708 -1.0  0.472135  0.87111  1.000000  1.0
# feature4   351.0  0.044372  0.441435 -1.0 -0.064735  0.01631  0.194185  1.0
# feature5   351.0  0.601068  0.519862 -1.0  0.412660  0.80920  1.000000  1.0
# feature6   351.0  0.115889  0.460810 -1.0 -0.024795  0.02280  0.334655  1.0
# feature7   351.0  0.550095  0.492654 -1.0  0.211310  0.72873  0.969240  1.0
# feature8   351.0  0.119360  0.520750 -1.0 -0.054840  0.01471  0.445675  1.0
# feature9   351.0  0.511848  0.507066 -1.0  0.087110  0.68421  0.953240  1.0
# feature10  351.0  0.181345  0.483851 -1.0 -0.048075  0.01829  0.534195  1.0
# feature11  351.0  0.476183  0.563496 -1.0  0.021120  0.66798  0.957895  1.0
# feature12  351.0  0.155040  0.494817 -1.0 -0.065265  0.02825  0.482375  1.0
# feature13  351.0  0.400801  0.622186 -1.0  0.000000  0.64407  0.955505  1.0
# feature14  351.0  0.093414  0.494873 -1.0 -0.073725  0.03027  0.374860  1.0
# feature15  351.0  0.344159  0.652828 -1.0  0.000000  0.60194  0.919330  1.0
# feature16  351.0  0.071132  0.458371 -1.0 -0.081705  0.00000  0.308975  1.0
# feature17  351.0  0.381949  0.618020 -1.0  0.000000  0.59091  0.935705  1.0
# feature18  351.0 -0.003617  0.496762 -1.0 -0.225690  0.00000  0.195285  1.0
# feature19  351.0  0.359390  0.626267 -1.0  0.000000  0.57619  0.899265  1.0
# feature20  351.0 -0.024025  0.519076 -1.0 -0.234670  0.00000  0.134370  1.0
# feature21  351.0  0.336695  0.609828 -1.0  0.000000  0.49909  0.894865  1.0
# feature22  351.0  0.008296  0.518166 -1.0 -0.243870  0.00000  0.188760  1.0
# feature23  351.0  0.362475  0.603767 -1.0  0.000000  0.53176  0.911235  1.0
# feature24  351.0 -0.057406  0.527456 -1.0 -0.366885  0.00000  0.164630  1.0
# feature25  351.0  0.396135  0.578451 -1.0  0.000000  0.55389  0.905240  1.0
# feature26  351.0 -0.071187  0.508495 -1.0 -0.332390 -0.01505  0.156765  1.0
# feature27  351.0  0.541641  0.516205 -1.0  0.286435  0.70824  0.999945  1.0
# feature28  351.0 -0.069538  0.550025 -1.0 -0.443165 -0.01769  0.153535  1.0
# feature29  351.0  0.378445  0.575886 -1.0  0.000000  0.49664  0.883465  1.0
# feature30  351.0 -0.027907  0.507974 -1.0 -0.236885  0.00000  0.154075  1.0
# feature31  351.0  0.352514  0.571483 -1.0  0.000000  0.44277  0.857620  1.0
# feature32  351.0 -0.003794  0.513574 -1.0 -0.242595  0.00000  0.200120  1.0
# feature33  351.0  0.349364  0.522663 -1.0  0.000000  0.40956  0.813765  1.0
# feature34  351.0  0.014480  0.468337 -1.0 -0.165350  0.00000  0.171660  1.0

# %%
for feature in df:
    print(feature)
    print(len(df[feature].unique()))
# Out:
# feature1
# 2
# feature2
# 1
# feature3
# 219
# feature4
# 269
# feature5
# 204
# feature6
# 259
# feature7
# 231
# feature8
# 260
# feature9
# 244
# feature10
# 267
# feature11
# 246
# feature12
# 269
# feature13
# 238
# feature14
# 266
# feature15
# 234
# feature16
# 270
# feature17
# 254
# feature18
# 280
# feature19
# 254
# feature20
# 266
# feature21
# 248
# feature22
# 265
# feature23
# 248
# feature24
# 264
# feature25
# 256
# feature26
# 273
# feature27
# 256
# feature28
# 281
# feature29
# 244
# feature30
# 266
# feature31
# 243
# feature32
# 263
# feature33
# 245
# feature34
# 263
# label
# 2

# %%
df['feature2'].unique()
# Out:
# array([0], dtype=int64)

# %%
df.drop(df.columns[1], inplace=True, axis=1)

# %%
df.head()
# Out:
#    feature1  feature3  feature4  feature5  feature6  feature7  feature8  \
# 0         1   0.99539  -0.05889   0.85243   0.02306   0.83398  -0.37708
# 1         1   1.00000  -0.18829   0.93035  -0.36156  -0.10868  -0.93597
# 2         1   1.00000  -0.03365   1.00000   0.00485   1.00000  -0.12062
# 3         1   1.00000  -0.45161   1.00000   1.00000   0.71216  -1.00000
# 4         1   1.00000  -0.02401   0.94140   0.06531   0.92106  -0.23255
#
#    feature9  feature10  feature11  ...  feature26  feature27  feature28  \
# 0   1.00000    0.03760    0.85243  ...   -0.51171    0.41078   -0.46168
# 1   1.00000   -0.04549    0.50874  ...   -0.26569   -0.20468   -0.18401
# 2   0.88965    0.01198    0.73082  ...   -0.40220    0.58984   -0.22145
# 3   0.00000    0.00000    0.00000  ...    0.90695    0.51613    1.00000
# 4   0.77152   -0.16399    0.52798  ...   -0.65158    0.13290   -0.53206
#
#    feature29  feature30  feature31  feature32  feature33  feature34  label
# 0    0.21266   -0.34090    0.42267   -0.54487    0.18641   -0.45300      g
# 1   -0.19040   -0.11593   -0.16626   -0.06288   -0.13738   -0.02447      b
# 2    0.43100   -0.17365    0.60436   -0.24180    0.56045   -0.38238      g
# 3    1.00000   -0.20099    0.25682    1.00000   -0.32382    1.00000      b
# 4    0.02431   -0.62197   -0.05707   -0.59573   -0.04608   -0.65697      g
#
# [5 rows x 34 columns]

# %%
df.ndim
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 34 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature1   351 non-null    int64
#  1   feature3   351 non-null    float64
#  2   feature4   351 non-null    float64
#  3   feature5   351 non-null    float64
#  4   feature6   351 non-null    float64
#  5   feature7   351 non-null    float64
#  6   feature8   351 non-null    float64
#  7   feature9   351 non-null    float64
#  8   feature10  351 non-null    float64
#  9   feature11  351 non-null    float64
#  10  feature12  351 non-null    float64
#  11  feature13  351 non-null    float64
#  12  feature14  351 non-null    float64
#  13  feature15  351 non-null    float64
#  14  feature16  351 non-null    float64
#  15  feature17  351 non-null    float64
#  16  feature18  351 non-null    float64
#  17  feature19  351 non-null    float64
#  18  feature20  351 non-null    float64
#  19  feature21  351 non-null    float64
#  20  feature22  351 non-null    float64
#  21  feature23  351 non-null    float64
#  22  feature24  351 non-null    float64
#  23  feature25  351 non-null    float64
#  24  feature26  351 non-null    float64
#  25  feature27  351 non-null    float64
#  26  feature28  351 non-null    float64
#  27  feature29  351 non-null    float64
#  28  feature30  351 non-null    float64
#  29  feature31  351 non-null    float64
#  30  feature32  351 non-null    float64
#  31  feature33  351 non-null    float64
#  32  feature34  351 non-null    float64
#  33  label      351 non-null    object
# dtypes: float64(32), int64(1), object(1)
# memory usage: 93.4+ KB

# %%
'''for feature in df:
    print(feature)
    df[feature].hist()
    plt.show()'''

# df.hist()
# plt.show()
# Out:
# 'for feature in df:\n    print(feature)\n    df[feature].hist()\n    plt.show()'

# %%
# Check summary statistics
df.describe()
# Out:
#          feature1    feature3    feature4    feature5    feature6    feature7  \
# count  351.000000  351.000000  351.000000  351.000000  351.000000  351.000000
# mean     0.891738    0.641342    0.044372    0.601068    0.115889    0.550095
# std      0.311155    0.497708    0.441435    0.519862    0.460810    0.492654
# min      0.000000   -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 25%      1.000000    0.472135   -0.064735    0.412660   -0.024795    0.211310
# 50%      1.000000    0.871110    0.016310    0.809200    0.022800    0.728730
# 75%      1.000000    1.000000    0.194185    1.000000    0.334655    0.969240
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          feature8    feature9   feature10   feature11  ...   feature25  \
# count  351.000000  351.000000  351.000000  351.000000  ...  351.000000
# mean     0.119360    0.511848    0.181345    0.476183  ...    0.396135
# std      0.520750    0.507066    0.483851    0.563496  ...    0.578451
# min     -1.000000   -1.000000   -1.000000   -1.000000  ...   -1.000000
# 25%     -0.054840    0.087110   -0.048075    0.021120  ...    0.000000
# 50%      0.014710    0.684210    0.018290    0.667980  ...    0.553890
# 75%      0.445675    0.953240    0.534195    0.957895  ...    0.905240
# max      1.000000    1.000000    1.000000    1.000000  ...    1.000000
#
#         feature26   feature27   feature28   feature29   feature30   feature31  \
# count  351.000000  351.000000  351.000000  351.000000  351.000000  351.000000
# mean    -0.071187    0.541641   -0.069538    0.378445   -0.027907    0.352514
# std      0.508495    0.516205    0.550025    0.575886    0.507974    0.571483
# min     -1.000000   -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 25%     -0.332390    0.286435   -0.443165    0.000000   -0.236885    0.000000
# 50%     -0.015050    0.708240   -0.017690    0.496640    0.000000    0.442770
# 75%      0.156765    0.999945    0.153535    0.883465    0.154075    0.857620
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#         feature32   feature33   feature34
# count  351.000000  351.000000  351.000000
# mean    -0.003794    0.349364    0.014480
# std      0.513574    0.522663    0.468337
# min     -1.000000   -1.000000   -1.000000
# 25%     -0.242595    0.000000   -0.165350
# 50%      0.000000    0.409560    0.000000
# 75%      0.200120    0.813765    0.171660
# max      1.000000    1.000000    1.000000
#
# [8 rows x 33 columns]

# %% [markdown]
# - Check Missing Values ( If Exist ; Fill each record with mean of its feature ) or any usless column.

# %%
# Find missing values
df.isnull().sum()
# Out:
# feature1     0
# feature3     0
# feature4     0
# feature5     0
# feature6     0
# feature7     0
# feature8     0
# feature9     0
# feature10    0
# feature11    0
# feature12    0
# feature13    0
# feature14    0
# feature15    0
# feature16    0
# feature17    0
# feature18    0
# feature19    0
# feature20    0
# feature21    0
# feature22    0
# feature23    0
# feature24    0
# feature25    0
# feature26    0
# feature27    0
# feature28    0
# feature29    0
# feature30    0
# feature31    0
# feature32    0
# feature33    0
# feature34    0
# label        0
# dtype: int64

# %%
df['label'] = [1 if lbl == 'g' else 0 for lbl in df['label']]

# %%
train_data = df.sample(frac= 0.6, random_state=125)
test_data = df.drop(train_data.index)

# %%
train_label = train_data.iloc[:,-1]
train_data = train_data.iloc[:,0:-1]
test_label = test_data.iloc[:,-1]
test_data = test_data.iloc[:,0:-1]

# %%
# df.drop(columns= 'label', inplace = True)

# %%
train_data.head()
# Out:
#      feature1  feature3  feature4  feature5  feature6  feature7  feature8  \
# 270         1   1.00000   0.08013   0.96775  -0.00482   0.96683  -0.00722
# 116         1   1.00000  -0.14754   1.00000   0.04918   0.57377  -0.01639
# 135         1   0.89706   0.38235   0.91176   0.37500   0.74265   0.67647
# 91          1   0.84557  -0.08580  -0.31745  -0.80553  -0.08961  -0.56435
# 100         1   1.00000  -1.00000   0.00000   0.00000   0.77941  -0.99265
#
#      feature9  feature10  feature11  ...  feature25  feature26  feature27  \
# 270   0.87980   -0.03923    1.00000  ...    0.98164    0.02003    0.93772
# 116   0.65574    0.01639    0.85246  ...    0.31148   -0.34426    0.52385
# 135   0.45588    0.77941    0.19118  ...   -0.74265   -0.12500   -0.67925
# 91    0.80648    0.04576    0.89514  ...    0.78932   -0.03718    0.70882
# 100   0.80882    0.55147   -0.41912  ...   -1.00000   -1.00000   -1.00000
#
#      feature28  feature29  feature30  feature31  feature32  feature33  \
# 270   -0.03034    1.00000   -0.05843    0.92774   -0.03464    0.92226
# 116   -0.20325    0.32787   -0.03279    0.27869   -0.44262    0.49180
# 135   -0.24131   -0.55147   -0.42647   -0.44118   -0.50735   -0.28676
# 91    -0.25288    0.77884   -0.14109   -0.21354   -0.78170   -0.18494
# 100   -1.00000    1.00000   -1.00000    1.00000   -1.00000    0.00000
#
#      feature34
# 270   -0.03673
# 116   -0.06557
# 135   -0.56618
# 91    -0.59867
# 100    0.00000
#
# [5 rows x 33 columns]

# %%
train_label
# Out:
# 270    1
# 116    0
# 135    1
# 91     0
# 100    0
#       ..
# 213    1
# 161    1
# 141    1
# 59     0
# 113    1
# Name: label, Length: 211, dtype: int64

# %% [markdown]
# - Standardized the Input Variables. **Hint**: Centeralized the data

# %%
#Normalize the data
train_mean = train_data.mean()
train_data -= train_mean
train_std = train_data.std()
train_data /= train_std
test_data -= train_mean
test_data /= train_std

# %% [markdown]
# - Encode labels.

# %%
train_data.shape
# Out:
# (211, 33)

# %%
test_data.shape
# Out:
# (140, 33)

# %%
train_label.shape
# Out:
# (211,)

# %%
test_label.shape
# Out:
# (140,)

# %%
train_label.sum()
# Out:
# 140

# %%
len(train_label)
# Out:
# 211

# %%
# train_label.sum()/len(train_label)

# %% [markdown]
# ### Data Preprocessing

# %%
train_data = train_data.to_numpy()

# %%
train_label = train_label.to_numpy().astype('float32')

# %%
test_data = test_data.to_numpy()

# %%
test_label = test_label.to_numpy().astype('float32')

# %%
#train_set = np.array(train_set.as_matrix())
#train_label = np.array(pd.DataFrame(train_label).as_matrix())

# %%
print(type(train_data))
print(type(train_label))
print(type(test_data))
print(type(test_label))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(train_data.dtype)
print(train_label.dtype)
print(test_label.dtype)
print(test_data.dtype)
# Out:
# float64
# float32
# float32
# float64

# %% [markdown]
# ### Model Architecture

# %% [markdown]
# - Model : 1 hidden layers including 16 unit.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Define model
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(train_data.shape[1],)))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1,  activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 128)               4352
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 12,673
# Trainable params: 12,673
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)

# %%
from tensorflow.keras import optimizers

model.compile(optimizer = 'RMSprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_data, train_label, validation_split=0.25, epochs= 70, batch_size = 32)
# Out:
# Epoch 1/70
# 5/5 [==============================] - 0s 31ms/step - loss: 0.6834 - accuracy: 0.5823 - val_loss: 0.5131 - val_accuracy: 0.8868
# Epoch 2/70
# 5/5 [==============================] - 0s 7ms/step - loss: 0.5305 - accuracy: 0.8101 - val_loss: 0.4269 - val_accuracy: 0.9245
# Epoch 3/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4768 - accuracy: 0.7975 - val_loss: 0.3702 - val_accuracy: 0.9245
# Epoch 4/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3985 - accuracy: 0.8418 - val_loss: 0.3286 - val_accuracy: 0.9434
# Epoch 5/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3795 - accuracy: 0.8734 - val_loss: 0.2974 - val_accuracy: 0.9434
# Epoch 6/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3347 - accuracy: 0.9241 - val_loss: 0.2701 - val_accuracy: 0.9623
# Epoch 7/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3278 - accuracy: 0.8797 - val_loss: 0.2432 - val_accuracy: 0.9623
# Epoch 8/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2967 - accuracy: 0.8987 - val_loss: 0.2224 - val_accuracy: 0.9623
# Epoch 9/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2427 - accuracy: 0.8987 - val_loss: 0.2163 - val_accuracy: 0.9623
# Epoch 10/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2456 - accuracy: 0.9177 - val_loss: 0.2057 - val_accuracy: 0.9623
# Epoch 11/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2309 - accuracy: 0.9114 - val_loss: 0.2015 - val_accuracy: 0.9623
# Epoch 12/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2483 - accuracy: 0.9241 - val_loss: 0.1981 - val_accuracy: 0.9434
# Epoch 13/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1881 - accuracy: 0.9304 - val_loss: 0.1965 - val_accuracy: 0.9623
# Epoch 14/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2040 - accuracy: 0.9241 - val_loss: 0.1846 - val_accuracy: 0.9623
# Epoch 15/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1785 - accuracy: 0.9177 - val_loss: 0.1793 - val_accuracy: 0.9623
# Epoch 16/70
# 5/5 [==============================] - ETA: 0s - loss: 0.2100 - accuracy: 0.93 - 0s 5ms/step - loss: 0.1798 - accuracy: 0.9367 - val_loss: 0.1818 - val_accuracy: 0.9623
# Epoch 17/70
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1757 - accuracy: 0.9367 - val_loss: 0.1770 - val_accuracy: 0.9623
# Epoch 18/70
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1699 - accuracy: 0.9430 - val_loss: 0.1750 - val_accuracy: 0.9434
# Epoch 19/70
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1631 - accuracy: 0.9367 - val_loss: 0.1745 - val_accuracy: 0.9434
# Epoch 20/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1531 - accuracy: 0.9494 - val_loss: 0.1727 - val_accuracy: 0.9623
# Epoch 21/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1558 - accuracy: 0.9304 - val_loss: 0.1750 - val_accuracy: 0.9434
# Epoch 22/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1445 - accuracy: 0.9557 - val_loss: 0.1653 - val_accuracy: 0.9623
# Epoch 23/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1319 - accuracy: 0.9557 - val_loss: 0.1676 - val_accuracy: 0.9623
# Epoch 24/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1218 - accuracy: 0.9494 - val_loss: 0.1627 - val_accuracy: 0.9623
# Epoch 25/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1166 - accuracy: 0.9557 - val_loss: 0.1652 - val_accuracy: 0.9434
# Epoch 26/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1327 - accuracy: 0.9494 - val_loss: 0.1622 - val_accuracy: 0.9623
# Epoch 27/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0948 - accuracy: 0.9684 - val_loss: 0.1769 - val_accuracy: 0.9623
# Epoch 28/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1144 - accuracy: 0.9494 - val_loss: 0.1673 - val_accuracy: 0.9434
# Epoch 29/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0882 - accuracy: 0.9557 - val_loss: 0.1609 - val_accuracy: 0.9623
# Epoch 30/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0806 - accuracy: 0.9684 - val_loss: 0.1652 - val_accuracy: 0.9623
# Epoch 31/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0941 - accuracy: 0.9684 - val_loss: 0.1615 - val_accuracy: 0.9623
# Epoch 32/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1042 - accuracy: 0.9620 - val_loss: 0.1674 - val_accuracy: 0.9811
# Epoch 33/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0858 - accuracy: 0.9684 - val_loss: 0.1796 - val_accuracy: 0.9623
# Epoch 34/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0814 - accuracy: 0.9747 - val_loss: 0.1717 - val_accuracy: 0.9623
# Epoch 35/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0696 - accuracy: 0.9873 - val_loss: 0.1483 - val_accuracy: 0.9811
# Epoch 36/70
# 5/5 [==============================] - ETA: 0s - loss: 0.0814 - accuracy: 0.93 - 0s 6ms/step - loss: 0.0699 - accuracy: 0.9684 - val_loss: 0.1693 - val_accuracy: 0.9623
# Epoch 37/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0708 - accuracy: 0.9747 - val_loss: 0.1623 - val_accuracy: 0.9811
# Epoch 38/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0578 - accuracy: 0.9873 - val_loss: 0.1859 - val_accuracy: 0.9623
# Epoch 39/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0508 - accuracy: 1.0000 - val_loss: 0.1723 - val_accuracy: 0.9811
# Epoch 40/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0515 - accuracy: 0.9810 - val_loss: 0.1613 - val_accuracy: 0.9811
# Epoch 41/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0497 - accuracy: 0.9810 - val_loss: 0.1776 - val_accuracy: 0.9811
# Epoch 42/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0352 - accuracy: 0.9937 - val_loss: 0.1940 - val_accuracy: 0.9811
# Epoch 43/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0475 - accuracy: 0.9873 - val_loss: 0.1899 - val_accuracy: 0.9623
# Epoch 44/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0535 - accuracy: 0.9810 - val_loss: 0.1941 - val_accuracy: 0.9623
# Epoch 45/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0372 - accuracy: 0.9937 - val_loss: 0.2048 - val_accuracy: 0.9623
# Epoch 46/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0325 - accuracy: 1.0000 - val_loss: 0.1918 - val_accuracy: 0.9811
# Epoch 47/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0277 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 0.9811
# Epoch 48/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0404 - accuracy: 0.9937 - val_loss: 0.2102 - val_accuracy: 0.9811
# Epoch 49/70
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0293 - accuracy: 0.9873 - val_loss: 0.2298 - val_accuracy: 0.9623
# Epoch 50/70
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0309 - accuracy: 1.0000 - val_loss: 0.2180 - val_accuracy: 0.9623
# Epoch 51/70
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0332 - accuracy: 0.9937 - val_loss: 0.1990 - val_accuracy: 0.9811
# Epoch 52/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0527 - accuracy: 0.9873 - val_loss: 0.2215 - val_accuracy: 0.9434
# Epoch 53/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0290 - accuracy: 0.9937 - val_loss: 0.2280 - val_accuracy: 0.9623
# Epoch 54/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0356 - accuracy: 0.9937 - val_loss: 0.2071 - val_accuracy: 0.9811
# Epoch 55/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0226 - accuracy: 0.9937 - val_loss: 0.2195 - val_accuracy: 0.9434
# Epoch 56/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0279 - accuracy: 0.9937 - val_loss: 0.1934 - val_accuracy: 0.9811
# Epoch 57/70
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.1997 - val_accuracy: 0.9623
# Epoch 58/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0351 - accuracy: 0.9937 - val_loss: 0.2214 - val_accuracy: 0.9245
# Epoch 59/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9623
# Epoch 60/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.1977 - val_accuracy: 0.9623
# Epoch 61/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9623
# Epoch 62/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0200 - accuracy: 0.9873 - val_loss: 0.2301 - val_accuracy: 0.9623
# Epoch 63/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.2362 - val_accuracy: 0.9434
# Epoch 64/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0245 - accuracy: 0.9810 - val_loss: 0.2302 - val_accuracy: 0.9623
# Epoch 65/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0177 - accuracy: 0.9937 - val_loss: 0.2034 - val_accuracy: 0.9623
# Epoch 66/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0173 - accuracy: 0.9937 - val_loss: 0.2127 - val_accuracy: 0.9623
# Epoch 67/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0223 - accuracy: 0.9937 - val_loss: 0.2051 - val_accuracy: 0.9623
# Epoch 68/70
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.2203 - val_accuracy: 0.9623
# Epoch 69/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.1969 - val_accuracy: 0.9623
# Epoch 70/70
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0213 - accuracy: 0.9937 - val_loss: 0.2228 - val_accuracy: 0.9623

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(70)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
plt.plot(epochs, acc_values, 'bo', label='Training acc')
plt.plot(epochs, val_acc_values, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# - Evaluation Step
# - Prediction

# %%
score = model.evaluate(test_data, test_label)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2805 - accuracy: 0.9357

# %%
predictions=model.predict(test_data)

# %%
y_pred = (predictions > 0.5)

# %%
tf.math.confusion_matrix(
    test_label, y_pred, num_classes=2, weights=None, dtype=tf.dtypes.int32,
    name=None
)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[47,  8],
#        [ 2, 83]])>

# %%
 # It will evaluate the logical expression y_predict>0.25 and return True or False

# %%
np.count_nonzero(y_pred)
# Out:
# 91
